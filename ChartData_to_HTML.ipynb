# %%
import pandas as pd

# %%
# The path to our CSV file
file = "chart_data.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(file)
df.head()
# Out:
#    Unnamed: 0            City  Cloudiness Country        Date  Humidity  \
# 0           0          Albany          40      US  1563159923        60
# 1           1  Port Macquarie          40      AU  1563159968        29
# 2           2          Khilok          90      RU  1563160426        31
# 3           3        Yar-Sale          47      RU  1563160426        64
# 4           4          Zaysan           3      KZ  1563160427        35
#
#      Lat     Lng  Max Temp  Wind Speed
# 0  42.65  -73.75   296.480        4.60
# 1 -31.43  152.91   292.150        8.70
# 2  51.36  110.46   300.023        2.05
# 3  66.83   70.83   295.823        3.37
# 4  47.47   84.87   299.423        2.48

# %%
df.to_html
# Out:
# <bound method DataFrame.to_html of      Unnamed: 0               City  Cloudiness Country        Date  Humidity  \
# 0             0             Albany          40      US  1563159923        60
# 1             1     Port Macquarie          40      AU  1563159968        29
# 2             2             Khilok          90      RU  1563160426        31
# 3             3           Yar-Sale          47      RU  1563160426        64
# 4             4             Zaysan           3      KZ  1563160427        35
# 5             5            Qaanaaq         100      GL  1563160024        76
# 6             6       Richards Bay           0      ZA  1563160025        82
# 7             7           Tessalit           0      ML  1563160427        33
# 8             8             Atuona           0      PF  1563160001        75
# 9             9       Puerto Ayora           9      EC  1563160018        93
# 10           10             Rawson           0      AR  1563160054        72
# ...

# %%
>>> df.to_html('filename.html')
